# %%
import sys
sys.path.insert(0, '/nas/xd/projects/transformers/src')
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    Trainer,
    TrainingArguments, default_data_collator, set_seed,
    HfArgumentParser, TrainingArguments, TransfoXLConfig)
# Out:
# In utils/hub.py: default_cache_path: /home/xd/.cache/huggingface/hub->/nas/xd/.cache/torch/transformers/
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /nas/xd/projects/transformers/src/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1063         try:
# -> 1064             return importlib.import_module("." + module_name, self.__name__)
#    1065         except Exception as e:
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /nas/xd/projects/transformers/src/transformers/trainer.py in <module>
#      39 # isort: off
# ---> 40 from .integrations import (
#      41     default_hp_search_backend,
#
# /nas/xd/projects/transformers/src/transformers/integrations.py in <module>
#      70
# ---> 71 from .trainer_callback import ProgressCallback, TrainerCallback  # noqa: E402
#      72 from .trainer_utils import PREFIX_CHECKPOINT_DIR, BestRun, IntervalStrategy  # noqa: E402
#
# /nas/xd/projects/transformers/src/transformers/trainer_callback.py in <module>
#      26 from .trainer_utils import IntervalStrategy, has_length
# ---> 27 from .training_args import TrainingArguments
#      28 from .utils import logging
#
# /nas/xd/projects/transformers/src/transformers/training_args.py in <module>
#      66 if is_accelerate_available():
# ---> 67     from accelerate import PartialState
#      68     from accelerate.utils import DistributedType
#
# ImportError: cannot import name 'PartialState' from 'accelerate' (/nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/accelerate/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_20128/3498251238.py in <module>
#       1 import sys
#       2 sys.path.insert(0, '/nas/xd/projects/transformers/src')
# ----> 3 from transformers import (
#       4     AutoModelForCausalLM,
#       5     AutoTokenizer,
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /nas/xd/projects/transformers/src/transformers/utils/import_utils.py in __getattr__(self, name)
#    1052             value = self._get_module(name)
#    1053         elif name in self._class_to_module.keys():
# -> 1054             module = self._get_module(self._class_to_module[name])
#    1055             value = getattr(module, name)
#    1056         else:
#
# /nas/xd/projects/transformers/src/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1067                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1068                 f" traceback):\n{e}"
# -> 1069             ) from e
#    1070
#    1071     def __reduce__(self):
#
# RuntimeError: Failed to import transformers.trainer because of the following error (look up to see its traceback):
# cannot import name 'PartialState' from 'accelerate' (/nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/accelerate/__init__.py)

# %%
import transformers
transformers

# %%
cache_dir = '/nas/xd/.cache/torch/transformers/'
proxies = {'http': '192.168.50.1:1081'} 
model = AutoModelForCausalLM.from_pretrained('EleutherAI/gpt-j-6B', cache_dir=cache_dir, proxies = proxies)

tokenizer = AutoTokenizer.from_pretrained('EleutherAI/gpt-j-6B', cache_dir=cache_dir)
# Out:
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/24.2G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17491/1552063796.py in <module>
#       1 cache_dir = '/nas/xd/.cache/torch/transformers/'
#       2 proxies = {'http': '192.168.50.1:1081'}
# ----> 3 model = AutoModelForCausalLM.from_pretrained('EleutherAI/gpt-j-6B', cache_dir=cache_dir, proxies = proxies)
#       4
#       5 tokenizer = AutoTokenizer.from_pretrained('EleutherAI/gpt-j-6B', cache_dir=cache_dir)
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     463             model_class = _get_model_class(config, cls._model_mapping)
#     464             return model_class.from_pretrained(
# --> 465                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     466             )
#     467         raise ValueError(
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2206                         _commit_hash=commit_hash,
#    2207                     )
# -> 2208                     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    2209
#    2210                     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     418             resume_download=resume_download,
#     419             use_auth_token=use_auth_token,
# --> 420             local_files_only=local_files_only,
#     421         )
#     422
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     122             )
#     123
# --> 124         return fn(*args, **kwargs)
#     125
#     126     return _inner_fn  # type: ignore
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1286                 proxies=proxies,
#    1287                 resume_size=resume_size,
# -> 1288                 headers=headers,
#    1289             )
#    1290
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries)
#     528         disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     529     )
# --> 530     for chunk in r.iter_content(chunk_size=10 * 1024 * 1024):
#     531         if chunk:  # filter out keep-alive new chunks
#     532             progress.update(len(chunk))
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/requests/models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     626         else:
#     627             while not is_fp_closed(self._fp):
# --> 628                 data = self.read(amt=amt, decode_content=decode_content)
#     629
#     630                 if data:
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     565
#     566         with self._error_catcher():
# --> 567             data = self._fp_read(amt) if not fp_closed else b""
#     568             if amt is None:
#     569                 flush_decoder = True
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/site-packages/urllib3/response.py in _fp_read(self, amt)
#     523                 else:
#     524                     chunk_amt = max_chunk_amt
# --> 525                 data = self._fp.read(chunk_amt)
#     526                 if not data:
#     527                     break
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/http/client.py in readinto(self, b)
#     489         # connection, and the user is reading more bytes than will be provided
#     490         # (for example, reading in 1k chunks)
# --> 491         n = self.fp.readinto(b)
#     492         if not n and b:
#     493             # Ideally, we would raise IncompleteRead if the content-length
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1047                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1048                   self.__class__)
# -> 1049             return self.read(nbytes, buffer)
#    1050         else:
#    1051             return super().recv_into(buffer, nbytes, flags)
#
# /nas2/lishengping/miniconda3/envs/xl-dialogue/lib/python3.7/ssl.py in read(self, len, buffer)
#     906         try:
#     907             if buffer is not None:
# --> 908                 return self._sslobj.read(len, buffer)
#     909             else:
#     910                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
