# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
from captum.attr import visualization as viz
from captum.attr import LayerConductance, LayerIntegratedGradients
import pickle
with open('/nas/xd/data/waf/picture_data_two','rb') as f:
    ans22 = pickle.load(f)

# %%
all_pictures = []
for i in range(len(ans22)):
    all_pictures.append(viz.VisualizationDataRecord(
                        ans22[i][0], #attr
                        ans22[i][1], # 概率
                        ans22[i][2], #预测label
                        ans22[i][3],#真实label
                        ans22[i][4],
                        ans22[i][5],       
                        ans22[i][6],
                        0.1))

# %%
print('\033[1m', 'Visualizations For Start Position', '\033[0m')
aaa = viz.visualize_text(all_pictures)
# Out:
#  Visualizations For Start Position
# ...

# %%
with open('/nas/xd/data/waf/picture_data_two','wb') as f:
    pickle.dump(ans22,f,-1)
